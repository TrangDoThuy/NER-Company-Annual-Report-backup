# %%
import re
import spacy
from spacy import displacy
from boilerpy3 import extractors
nlp = spacy.load("en_core_web_sm")

# %%
# Condenses all repeating newline characters into one single newline character
def condense_newline(text):
    return '\n'.join([p for p in re.split('\n|\r', text) if len(p) > 0])

# %%
# Returns the text from a HTML file
def parse_html(html_path):
    # Text extraction with boilerpy3
    html_extractor = extractors.ArticleExtractor()
    return condense_newline(html_extractor.get_content_from_file(html_path))

# %%
html_path = ("Data/NYSE/Agilent Technologies Inc/annual_report_2002-01-22_f78349e10-k.htm")
text = parse_html(html_path)
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Includes operations from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 1, 2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 31, 2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the measurement date.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Financial Condition
# Liquidity and Capital
# 	Resources
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Our financial position remained strong at</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 31, 2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with cash and cash equivalents of</br>$
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1,170
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  million.</br>Cash usage from our continuing operations was</br>$114 million in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . We generated cash from continuing</br>operations of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $536 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  compared to</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $341 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , accounts payable used cash</br>of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $480 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  and income tax payable used cash of</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $472 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  offset by a decrease in outstanding accounts</br>receivable totaling
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $933 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , cash</br>from continuing operations was primarily a result of net</br>earnings. In addition, lower cash from continuing operations in</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  resulted from a significant increase in accounts receivable</br>due to particularly strong shipments in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>Net cash utilized for investing activities was</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1,365 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  compared to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1,062 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for</br>2000 and $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     336
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  million for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In all periods, capital</br>expenditures for p

# %%
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# November 1, 2000 DATE
# May 31, 2001 DATE
# Financial Condition
# Liquidity and Capital
# 	Resources ORG
# October 31, 2001 DATE
# 1,170 MONEY
# 2001 DATE
# $536 million MONEY
# 2000 DATE
# $341 million MONEY
# 1999 DATE
# 2001 DATE
# $480 million MONEY
# $472 million MONEY
# $933 million MONEY
# 2000 DATE
# 1999 DATE
# 1999 DATE
# October 1999 DATE
# $1,365 million MONEY
# 2001 DATE
# $1,062 million MONEY
# 336 MONEY
# 1999 DATE
# $904 million MONEY
# $881 million MONEY
# 2001 DATE
# 2000 DATE
# first ORDINAL
# second ORDINAL
# Yokagawa ORG
# Agilent Technologies Japan ORG
# Agilent Technologies ORG
# Japan, Ltd.’s ORG
# Yokogawa ORG
# January 2001 DATE
# HP ORG
# 39 CARDINAL
# Table of Contents WORK_OF_ART
# Yokogawa ORG
# November 1999 DATE
# 2001 DATE
# Tyco Capital ORG
# $287 million MONEY
# two CARDINAL
# the end of 2001 DATE
# November 5 DATE
# 2005 DATE
# 364-day DATE
# November 2, 2001 DATE
# November 2001 DATE
# November 1, 2002 DATE
# November 19, 2001 DATE
# January 5, 2001 DATE
# $690 million MONEY
# February 2001 DATE
# California GPE
# $287 million MONEY
# August 2001 DATE
# California GPE
# 289 MONEY
# August 1, 2001 DATE
# approximately $1.6 billion MONEY
# approximately $80 million MONEY
# the year DATE
# November 27, 2001 DATE
# $1.15 billion MONEY
# 3 percent PERCENT
# 2021 DATE
# 32.22 MONEY
# December 2004 DATE
# 2006 DATE
# 2011 DATE
# 2016 DATE
# November 1, 1999 DATE
# HP ORG
# daily DATE
# HP ORG
# October DATE
# 31, 1999 DATE
# 1998 DATE
# HP ORG
# November 1, 1999 DATE
# HP ORG
# November DATE
# December 1999 DATE
# HP ORG
# $1.3 billion MONEY
# HP ORG
# approximately $0.5 billion MONEY
# Yokogawa ORG
# 25 percent PERCENT
# Agilent NORP
# $2.1 billion MONEY
# November 1999 DATE
# HP ORG
# $1.8 billion MONEY
# HP ORG
# $1.1 billion MONEY
# $0.7 billion MONEY
# the year ended
#  DATE
# October 31, 2000 DATE
# 40 CARDINAL
# Table of Contents
# Factors That May Affect Future
# Results WORK_OF_ART
# September 11, 2001 DATE
# five CARDINAL
# the past six quarters DATE
# Earlier this year DATE
# approximately 4,000 CARDINAL
# 9 percent PERCENT
# the middle of 2002 DATE
# May 1 DATE
# October 31 of this year DATE
# 10 percent PERCENT
# 10 percent PERCENT
# hours TIME
# November 15, 2001 DATE
# approximately 4,000 CARDINAL
# 10 percent PERCENT
# approximately 2,000 CARDINAL
# the first quarter fiscal
# 2002 DATE
# 5 percent PERCENT
# February 2002 DATE
# 41 CARDINAL
# Table of Contents WORK_OF_ART
# the year DATE
# October 31, 2001 DATE
# approximately $459 million MONEY
# quarterly DATE
# quarterly DATE
# the quarter DATE
# Hewlett-Packard ORG
# 42 CARDINAL
# Table of Contents WORK_OF_ART
# the United States GPE
# September 11, 2001 DATE
# U.S. GPE
# Southeast Asia LOC
# 43 CARDINAL
# the past year DATE
# third ORDINAL
# a given quarter DATE
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# the twelve months ended October 31, 2001 DATE
# Hewlett-Packard ORG
# approximately 30.7 percent CARDINAL
# 44 CARDINAL
# Table of Contents WORK_OF_ART
# Hewlett-Packard ORG
# Hewlett-Packard’s ORG
# November 2002 DATE
# November 2009 DATE
# third ORDINAL
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# the United States Environmental GPE
# the Toxic Substances Control Act ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# 45 CARDINAL
# Table of Contents WORK_OF_ART
# United States GPE
# the
# International Standards Organization ORG
# the United States Federal Communications GPE
# the Federal Food, Drug ORG
# Third ORDINAL
# Third ORDINAL
# third ORDINAL
# 46 CARDINAL
# Table of Contents WORK_OF_ART
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Hewlett-Packard’s ORG
# third ORDINAL
# Hewlett-Packard ORG
# Hewlett-Packard’s ORG
# Hewlett-Packard’s ORG
# Hewlett-Packard ORG
# Hewlett-Packard ORG
# Third ORDINAL
# Agilent Laboratories ORG
# California GPE
# Washington GPE
# Japan GPE
# California GPE
# California GPE
# California GPE
# 47 CARDINAL
# California GPE
# Item  PERSON
# Qualitative Disclosures About Market Risk ORG
# United States GPE
# 10% PERCENT
# October 31, 2001 and 2000 DATE
# Item  PERSON
# Supplementary Data ORG
# The Financial Statements ORG
# Item  PERSON
# Item  PERSON
# Election of Directors WORK_OF_ART
# Proxy
# Statement for the Annual Meeting of Stockholders (the
#  WORK_OF_ART
# Proxy Statement WORK_OF_ART
# February  DATE
# 22, 2002 DATE
# the Proxy Statement ORG
# Registrant ORG
# Beneficial Ownership ORG
# the Securities Exchange Act ORG
# 1934 DATE
# Beneficial Ownership ORG
# the Proxy Statement ORG
# Item  PERSON
# the Proxy Statement FAC
# Compensation Arrangements PERSON
# the Proxy Statement ORG
# the Proxy Statement ORG
# Item  PERSON
# 10-12 CARDINAL
# 48 CARDINAL
# the Proxy Statement PERSON
# Item  PERSON
# Item  PERSON
# Reports PERSON
# 1 CARDINAL
