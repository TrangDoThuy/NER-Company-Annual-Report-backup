# %%
import pandas as pd
df = pd.read_csv('list_10_K.csv')

# %%
df
# Out:
#        cik_number                    company_name form_type        date  \
# 0          796343               ADOBE SYSTEMS INC      10-K  2006-02-08
# 1          796343               ADOBE SYSTEMS INC      10-K  2007-02-05
# 2         1080224                EDGAR ONLINE INC      10-K  2008-03-17
# 3          796343               ADOBE SYSTEMS INC      10-K  2008-01-24
# 4          883984              ICU MEDICAL INC/DE      10-K  2008-02-22
# ...           ...                             ...       ...         ...
# 61330      935419  RCI HOSPITALITY HOLDINGS, INC.      10-K  2020-12-14
# 61331      936395                      CIENA CORP      10-K  2020-12-18
# 61332      936528          WASHINGTON FEDERAL INC      10-K  2020-11-23
# 61333      949852      THANKSGIVING COFFEE CO INC      10-K  2020-10-26
# 61334       96699   TECHNICAL COMMUNICATIONS CORP      10-K  2020-12-28
#
#                                                 filename
# ...

# %%
folder_url_list=[]
for index,url in enumerate(df.filename):
    folder_url = url.replace('-','').replace('.txt','')
    folder_url_list.append(folder_url)
df['folder_url']=folder_url_list

# %%
df
# Out:
#        cik_number                    company_name form_type        date  \
# 0          796343               ADOBE SYSTEMS INC      10-K  2006-02-08
# 1          796343               ADOBE SYSTEMS INC      10-K  2007-02-05
# 2         1080224                EDGAR ONLINE INC      10-K  2008-03-17
# 3          796343               ADOBE SYSTEMS INC      10-K  2008-01-24
# 4          883984              ICU MEDICAL INC/DE      10-K  2008-02-22
# ...           ...                             ...       ...         ...
# 61330      935419  RCI HOSPITALITY HOLDINGS, INC.      10-K  2020-12-14
# 61331      936395                      CIENA CORP      10-K  2020-12-18
# 61332      936528          WASHINGTON FEDERAL INC      10-K  2020-11-23
# 61333      949852      THANKSGIVING COFFEE CO INC      10-K  2020-10-26
# 61334       96699   TECHNICAL COMMUNICATIONS CORP      10-K  2020-12-28
#
#                                                 filename  \
# ...

# %%
df.to_csv('list_10_K.csv',index=False)
